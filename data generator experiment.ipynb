# %%
# Loading up the libraries

import numpy as np
import os
import pandas as pd
import datetime
import xarray as xr
import tensorflow as tf
import glob

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
os.chdir("C://Users//Greg//code//space physics//experiment//data")

# %%
ss_file = "substorms_2000_2018.csv"
ss = pd.read_csv(ss_file)
ss.index = pd.to_datetime(ss.Date_UTC)
ss = ss.drop(columns=['Date_UTC'])

mag_file = "mag_data_2000.nc"
mag_data = xr.open_dataset(mag_file)

f = np.load("statistics.npz")
mean = f['mean']
std = f['std']

# %%
mag_data = mag_data.sel(dim_1=['MLT','MLAT','N','E','Z'])
time_idx = mag_data.Date_UTC[0].values
data_dt = np.timedelta64(20, 'm')
predict_dt = np.timedelta64(200, 'm')
chunk = mag_data.sel(Date_UTC=slice(time_idx, time_idx+data_dt))
cond = np.isnan(chunk).any(dim=['Date_UTC', 'dim_1'])
drop = [st for st in cond if cond[st]]
chunk = chunk.drop(drop)
mag_chunk = chunk.sel(dim_1=['N','E','Z']).to_array().values
print("mag chunk shape: ", mag_chunk.shape)

mlt = chunk.sel(dim_1='MLT').to_array()
mlat = chunk.sel(dim_1='MLAT').to_array()[:,0]
sinmlt = np.sin(mlt).mean(dim='Date_UTC')
cosmlt = np.cos(mlt).mean(dim='Date_UTC')
st_loc = np.stack((sinmlt, cosmlt, mlat/90), axis=1)
print("station location shape: ", st_loc.shape)

target_chunk = ss[time_idx+data_dt:time_idx+data_dt+predict_dt]
yesno = len(target_chunk) > 0
first = target_chunk.iloc[0]
time = (first.name - (time_idx+data_dt)).total_seconds() / (200 * 60)
location = (np.sin(first['MLT'] * 2 * np.pi / 24), np.cos(first['MLT'] * 2 * np.pi / 24), first['MLAT']/90)

dataset = mag_data.copy()

da = dataset.to_array().values
sinmlt = np.sin(da[:,:,0])
cosmlt = np.cos(da[:,:,0])
mlat = da[:,:,1] / 90
nez = (da[:,:,2:] - mean) / std

data = np.concatenate((sinmlt[:,:,None], cosmlt[:,:,None], mlat[:,:,None], nez), axis=2)

xr.Dataset({st: (['Date_UTC', 'vals'], data[i]) for i,st in enumerate(dataset)}, 
          coords={'Date_UTC': dataset.Date_UTC, 'vals': ['SINMLT','COSMLT','MLAT','N','E','Z']})
# Out:
# mag chunk shape:  (159, 21, 3)
# station location shape:  (159, 3)
# <xarray.Dataset>
# Dimensions:   (Date_UTC: 507007, vals: 6)
# Coordinates:
#   * Date_UTC  (Date_UTC) datetime64[ns] 2000-01-01T00:13:00 ... 2000-12-31T23:59:00
#   * vals      (vals) <U6 'SINMLT' 'COSMLT' 'MLAT' 'N' 'E' 'Z'
# Data variables:
#     ABG       (Date_UTC, vals) float64 -0.9996 0.02761 0.1339 ... -0.018 -0.265
#     ABK       (Date_UTC, vals) float64 0.9613 -0.2756 ... -0.001211 0.6162
#     ALE       (Date_UTC, vals) float64 0.9857 -0.1684 0.9689 ... 0.005414 0.7297
#     AMK       (Date_UTC, vals) float64 nan nan nan ... -0.7975 0.01734 0.6521
#     AMS       (Date_UTC, vals) float64 -0.9162 -0.4008 -0.5457 ... 0.0222 -1.987
#     AND       (Date_UTC, vals) float64 0.984 -0.1782 0.7371 ... 0.004531 0.6199
#     API       (Date_UTC, vals) float64 -0.006371 1.0 -0.1727 ... 0.07697 -1.263
#     APL       (Date_UTC, vals) float64 0.1202 0.9928 0.5553 ... nan nan nan
#     ASC       (Date_UTC, vals) float64 -0.7166 -0.6975 ... 0.0005554 -1.236
#     ASP       (Date_UTC, vals) float64 0.5268 -0.85 -0.3772 ... -0.2079 -1.934
#     BDV       (Date_UTC, vals) float64 0.8573 0.5148 0.4999 ... -0.008278 0.4191
#     BEL       (Date_UTC, vals) float64 0.9949 0.1006 0.5316 ... -0.01049 0.4693
#     BET       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     BFE       (Date_UTC, vals) float64 0.8573 0.5148 0.5793 ... -0.004303 0.4968
#     BIK       (Date_UTC, vals) float64 0.501 -0.8654 -0.1017 ... -0.1152 -1.095
#     BJN       (Date_UTC, vals) float64 0.7589 -0.6512 ... -0.0007696 0.6599
#     BLC       (Date_UTC, vals) float64 -0.9136 -0.4066 ... 0.008506 0.8332
#     BMT       (Date_UTC, vals) float64 0.9772 0.2124 0.3856 ... 0.03191 0.5039
#     BNG       (Date_UTC, vals) float64 0.8772 0.4801 ... -0.01446 -1.003
#     BOR       (Date_UTC, vals) float64 nan nan nan ... -0.3066 -0.009603 0.5834
#     BOU       (Date_UTC, vals) float64 -0.6068 -0.7948 ... -0.02418 0.5843
#     BRW       (Date_UTC, vals) float64 -0.6935 0.7204 0.7806 ... -0.018 0.7485
#     BSL       (Date_UTC, vals) float64 -0.8864 0.4629 0.4608 ... -0.01049 0.4074
#     CBB       (Date_UTC, vals) float64 0.08785 -0.9961 0.858 ... -0.02153 0.8194
#     CBI       (Date_UTC, vals) float64 0.1344 -0.9909 0.2222 ... 0.1158 -0.08349
#     CCS       (Date_UTC, vals) float64 0.4766 0.8791 0.8001 ... nan nan nan
#     CHC       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     CHD       (Date_UTC, vals) float64 0.1935 -0.9811 0.7237 ... 0.02441 0.7739
#     CLF       (Date_UTC, vals) float64 0.3429 0.9394 0.4902 ... 0.003206 0.3846
#     CLK       (Date_UTC, vals) float64 0.3339 0.9426 0.6131 ... -0.01402 0.8166
#     CMO       (Date_UTC, vals) float64 0.09349 0.9956 ... -0.004745 0.7241
#     CNB       (Date_UTC, vals) float64 -0.7414 -0.671 -0.4853 ... -0.2569 -2.174
#     CNL       (Date_UTC, vals) float64 0.4776 -0.8786 0.8131 ... -0.04008 0.8261
#     CPS       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     CSY       (Date_UTC, vals) float64 -0.6984 0.7157 -0.8971 ... -0.018 -2.41
#     CTA       (Date_UTC, vals) float64 -0.3195 -0.9476 ... -0.2804 -1.767
#     CY0       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     CZT       (Date_UTC, vals) float64 0.8423 -0.539 -0.5894 ... 0.03191 -1.646
#     DAW       (Date_UTC, vals) float64 0.6001 0.7999 0.7349 ... -0.07011 0.7489
#     DIK       (Date_UTC, vals) float64 -0.7265 0.6872 0.7634 ... -0.01004 0.8002
#     DLR       (Date_UTC, vals) float64 -0.8921 -0.4518 0.434 ... -0.0233 0.3544
#     DMH       (Date_UTC, vals) float64 0.7174 0.6967 0.8589 ... -0.002978 0.6718
#     DOB       (Date_UTC, vals) float64 0.882 0.4713 0.6564 ... -0.0003279 0.5563
#     DOU       (Date_UTC, vals) float64 0.4969 0.8678 0.5164 ... -0.002095 0.4195
#     DRV       (Date_UTC, vals) float64 nan nan nan nan ... -1.889 0.694 -2.508
#     DVS       (Date_UTC, vals) float64 0.9857 -0.1684 -0.8278 ... nan nan nan
#     EAG       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     EKP       (Date_UTC, vals) float64 -0.993 -0.1185 0.7919 ... -0.01623 0.8352
#     ESK       (Date_UTC, vals) float64 0.2182 0.9759 0.5873 ... 0.002764 0.4827
#     EWA       (Date_UTC, vals) float64 0.465 0.8853 0.2383 ... -0.04229 -1.425
#     EYR       (Date_UTC, vals) float64 -0.4044 0.9146 -0.5556 ... 0.01204 -2.188
#     FAR       (Date_UTC, vals) float64 nan nan nan ... -0.4817 0.03457 0.5543
#     FCC       (Date_UTC, vals) float64 -0.9969 -0.07868 ... -0.007837 0.8326
#     FHB       (Date_UTC, vals) float64 0.3062 -0.952 0.7536 ... 0.02308 0.6805
#     FMC       (Date_UTC, vals) float64 0.1474 -0.9891 0.717 ... -0.0445 0.8002
#     FRD       (Date_UTC, vals) float64 0.07039 0.9975 ... -0.0003279 0.5536
#     FRN       (Date_UTC, vals) float64 0.3967 -0.9179 0.478 ... -0.0467 0.4253
#     FSP       (Date_UTC, vals) float64 0.9119 -0.4103 ... -0.004745 0.7991
#     FUR       (Date_UTC, vals) float64 0.7513 0.66 0.489 ... -0.006953 0.4008
#     GAK       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     GDH       (Date_UTC, vals) float64 0.2582 -0.9661 0.8414 ... 0.02308 0.718
#     GHB       (Date_UTC, vals) float64 nan nan nan ... -0.8802 0.02131 0.6998
#     GHC       (Date_UTC, vals) float64 nan nan nan nan ... -1.715 0.01911 0.8187
#     GIM       (Date_UTC, vals) float64 -0.9941 -0.1085 0.742 ... -0.01137 0.8233
#     GML       (Date_UTC, vals) float64 0.2377 0.9713 0.61 ... 0.009831 0.5035
#     GNA       (Date_UTC, vals) float64 0.948 0.3183 -0.4904 ... -0.1324 -2.185
#     GTF       (Date_UTC, vals) float64 0.5814 0.8136 0.5967 ... 0.004531 0.5812
#     GUA       (Date_UTC, vals) float64 -0.02522 -0.9997 ... 0.001439 -0.5365
#     GUI       (Date_UTC, vals) float64 -0.8952 -0.4457 ... -0.005628 -0.1057
#     HAD       (Date_UTC, vals) float64 0.04998 0.9988 0.5347 ... 0.002764 0.4257
#     HAN       (Date_UTC, vals) float64 0.8964 -0.4432 0.6501 ... -0.01093 0.5858
#     HBK       (Date_UTC, vals) float64 0.9854 0.17 -0.4022 ... -0.003861 -1.428
#     HER       (Date_UTC, vals) float64 0.5312 0.8473 ... -0.0007696 -1.386
#     HLL       (Date_UTC, vals) float64 -0.9996 0.02805 0.7137 ... 0.04384 0.5913
#     HLP       (Date_UTC, vals) float64 0.9871 0.1601 0.5643 ... -0.01535 0.498
#     HOB       (Date_UTC, vals) float64 -0.6781 -0.7349 ... -0.1677 -2.333
#     HON       (Date_UTC, vals) float64 0.465 0.8853 0.2383 ... -0.02948 -0.1599
#     HOP       (Date_UTC, vals) float64 0.3909 -0.9204 0.8126 ... 0.001881 0.6789
#     HRB       (Date_UTC, vals) float64 0.949 0.3153 0.4842 ... -0.006953 0.4103
#     HRN       (Date_UTC, vals) float64 0.6973 -0.7168 0.8243 ... -0.01446 0.6727
#     HTY       (Date_UTC, vals) float64 0.2713 -0.9625 0.291 ... 0.08094 0.1172
#     HUA       (Date_UTC, vals) float64 -0.03955 0.9992 ... -0.02992 -0.7345
#     IQA       (Date_UTC, vals) float64 0.9358 0.3526 0.81 ... 0.03633 0.7691
#     IRT       (Date_UTC, vals) float64 0.562 0.8271 0.5267 ... -0.004303 0.7793
#     JAN       (Date_UTC, vals) float64 nan nan nan nan ... -0.917 0.03059 0.6274
#     JAX       (Date_UTC, vals) float64 -0.3612 0.9325 0.4633 ... nan nan nan
#     KAG       (Date_UTC, vals) float64 0.7544 -0.6564 0.2754 ... 0.06416 0.1381
#     KAK       (Date_UTC, vals) float64 0.2423 -0.9702 0.3264 ... 0.08668 0.2051
#     KAV       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     KDU       (Date_UTC, vals) float64 0.663 -0.7486 -0.2416 ... -0.1664 -1.557
#     KEV       (Date_UTC, vals) float64 0.7185 -0.6956 ... -0.001211 0.6393
#     KIL       (Date_UTC, vals) float64 0.9174 -0.3979 ... -0.005186 0.6233
#     KIR       (Date_UTC, vals) float64 0.943 -0.3327 0.7173 ... -0.001211 0.6153
#     KNY       (Date_UTC, vals) float64 0.7478 -0.6639 0.2747 ... 0.1017 0.1352
#     KOU       (Date_UTC, vals) float64 0.9801 -0.1983 0.1037 ... 0.02352 -0.5495
#     KTN       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     KUV       (Date_UTC, vals) float64 0.03114 -0.9995 0.9022 ... nan nan nan
#     KVI       (Date_UTC, vals) float64 0.9939 0.1106 0.6212 ... -0.00872 0.5434
#     LEK       (Date_UTC, vals) float64 0.9999 0.0108 0.725 ... -0.0003279 0.6078
#     LER       (Date_UTC, vals) float64 0.4529 0.8916 0.6428 ... 0.004089 0.5345
#     LIV       (Date_UTC, vals) float64 0.7959 0.6055 -0.5308 ... 0.04958 -1.565
#     LNP       (Date_UTC, vals) float64 0.9978 -0.06597 ... 0.03722 -0.02774
#     LOV       (Date_UTC, vals) float64 0.9939 0.1106 0.6193 ... -0.007837 0.5433
#     LOZ       (Date_UTC, vals) float64 0.4364 -0.8998 0.7132 ... nan nan nan
#     LRM       (Date_UTC, vals) float64 0.9115 0.4114 -0.3699 ... -0.1138 -1.938
#     LRV       (Date_UTC, vals) float64 -0.9998 -0.02194 ... 0.02131 0.5959
#     LYC       (Date_UTC, vals) float64 0.994 -0.109 0.6803 ... -0.003861 0.5888
#     LYR       (Date_UTC, vals) float64 0.5742 -0.8187 0.8368 ... 0.003647 0.6803
#     MAB       (Date_UTC, vals) float64 0.548 0.8365 0.5184 ... -0.001211 0.4229
#     MAS       (Date_UTC, vals) float64 0.8314 -0.5557 ... -0.006953 0.6317
#     MAW       (Date_UTC, vals) float64 0.8772 0.4801 -0.7783 ... 0.04163 -1.961
#     MBO       (Date_UTC, vals) float64 -0.8009 -0.5988 ... -0.004745 -0.6066
#     MCG       (Date_UTC, vals) float64 -0.9203 -0.3912 0.8476 ... nan nan nan
#     MCM       (Date_UTC, vals) float64 -0.9053 -0.4248 -0.8881 ... nan nan nan
#     MCQ       (Date_UTC, vals) float64 -0.8228 0.5683 ... -0.09529 -2.433
#     MEA       (Date_UTC, vals) float64 0.2744 -0.9616 0.69 ... -0.03566 0.7774
#     MGD       (Date_UTC, vals) float64 -0.2621 -0.965 0.599 ... 0.02617 0.6555
#     MID       (Date_UTC, vals) float64 nan nan nan ... 1.016 -0.05377 -0.08966
#     MMB       (Date_UTC, vals) float64 0.004778 -1.0 0.4126 ... 0.06239 0.3765
#     MSH       (Date_UTC, vals) float64 0.6055 0.7958 0.5849 ... 0.02264 0.2404
#     MSR       (Date_UTC, vals) float64 nan nan nan nan ... 0.9093 0.1088 0.4045
#     MUO       (Date_UTC, vals) float64 0.8731 -0.4875 0.7179 ... -0.02109 0.6219
#     MUT       (Date_UTC, vals) float64 0.9994 -0.03601 ... 0.03987 -0.4575
#     NAL       (Date_UTC, vals) float64 0.6144 -0.789 0.8472 ... -0.03169 0.6828
#     NAQ       (Date_UTC, vals) float64 0.03114 -0.9995 0.7342 ... 0.03191 0.6554
#     NCK       (Date_UTC, vals) float64 0.9168 0.3993 0.4814 ... -0.009162 0.4036
#     NEW       (Date_UTC, vals) float64 0.4241 -0.9056 0.6102 ... -0.04759 0.6738
#     NGK       (Date_UTC, vals) float64 0.8468 0.5319 0.537 ... -0.003861 0.4566
#     NRD       (Date_UTC, vals) float64 0.8874 -0.4611 0.9012 ... -0.0361 0.6981
#     NUR       (Date_UTC, vals) float64 0.9556 -0.2948 0.63 ... -0.01181 0.5666
#     ONW       (Date_UTC, vals) float64 nan nan nan nan ... 1.46 0.1472 0.1122
#     OTT       (Date_UTC, vals) float64 0.2864 0.9581 0.6214 ... 0.0116 0.6691
#     OUJ       (Date_UTC, vals) float64 0.8423 -0.539 0.6758 ... -0.01049 0.6043
#     OUL       (Date_UTC, vals) float64 0.8731 -0.4875 0.683 ... -1.343 0.6023
#     PAF       (Date_UTC, vals) float64 -0.05837 -0.9983 ... 0.01999 -1.935
#     PBQ       (Date_UTC, vals) float64 0.1301 0.9915 0.7314 ... 0.0169 0.7818
#     PEL       (Date_UTC, vals) float64 0.8827 -0.4699 ... -0.009162 0.6141
#     PET       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     PHU       (Date_UTC, vals) float64 nan nan nan ... 2.415 0.007181 -0.1541
#     PIN       (Date_UTC, vals) float64 -0.9822 -0.1876 0.6741 ... -0.0202 0.7733
#     PKR       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     PPI       (Date_UTC, vals) float64 0.6851 -0.7284 0.408 ... nan nan nan
#     PPT       (Date_UTC, vals) float64 0.9977 0.06712 -0.1841 ... 0.08448 -1.258
#     PST       (Date_UTC, vals) float64 0.7898 0.6134 -0.4219 ... 0.04826 -1.338
#     RAL       (Date_UTC, vals) float64 -0.49 -0.8717 0.7487 ... 0.01822 0.8262
#     RAN       (Date_UTC, vals) float64 -0.9975 0.07118 0.8111 ... 0.03942 0.8328
#     RES       (Date_UTC, vals) float64 -0.5581 -0.8298 ... 0.005856 0.7863
#     RPB       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     RVK       (Date_UTC, vals) float64 0.9608 0.2771 0.6891 ... 0.005856 0.5808
#     S01       (Date_UTC, vals) float64 0.9837 0.1798 0.6807 ... 0.002764 0.5779
#     SBA       (Date_UTC, vals) float64 -0.9053 -0.4248 -0.8879 ... 0.4073 -2.392
#     SCO       (Date_UTC, vals) float64 -0.94 0.3411 0.7951 ... -0.004303 0.6401
#     SIT       (Date_UTC, vals) float64 0.9182 0.396 0.6659 ... -0.03699 0.696
#     SJG       (Date_UTC, vals) float64 nan nan nan ... 1.046 0.005856 -0.0008222
#     SKT       (Date_UTC, vals) float64 0.4088 -0.9126 0.7988 ... nan nan nan
#     SMI       (Date_UTC, vals) float64 0.3031 -0.953 0.7518 ... 0.01557 0.8188
#     SOD       (Date_UTC, vals) float64 0.8026 -0.5966 0.709 ... -0.005186 0.6229
#     SOR       (Date_UTC, vals) float64 0.8423 -0.539 0.7478 ... nan nan nan
#     SPA       (Date_UTC, vals) float64 0.9959 0.09023 -0.8231 ... nan nan nan
#     SPT       (Date_UTC, vals) float64 -0.9559 0.2937 ... -0.001653 0.2127
#     STF       (Date_UTC, vals) float64 0.1703 -0.9854 0.8118 ... 0.005856 0.7048
#     STJ       (Date_UTC, vals) float64 0.752 -0.6591 0.5964 ... 0.01734 0.5429
#     SUA       (Date_UTC, vals) float64 nan nan nan nan ... 0.4493 -0.0149 0.3914
#     SVS       (Date_UTC, vals) float64 0.5981 -0.8014 0.929 ... 0.01116 0.7402
#     TAL       (Date_UTC, vals) float64 -0.9496 -0.3134 0.8772 ... 0.01116 0.8122
#     TAM       (Date_UTC, vals) float64 0.2764 0.9611 ... -0.004745 -0.2796
#     TAN       (Date_UTC, vals) float64 nan nan nan nan ... 0.2449 0.1035 -1.461
#     THL       (Date_UTC, vals) float64 0.7651 -0.6439 0.9483 ... 0.008064 0.7435
#     THY       (Date_UTC, vals) float64 0.9284 0.3717 0.4721 ... -0.01093 0.3944
#     TIK       (Date_UTC, vals) float64 0.9338 -0.3579 ... -0.001211 0.8221
#     TRO       (Date_UTC, vals) float64 0.9396 -0.3421 ... -0.001653 0.6268
#     TRW       (Date_UTC, vals) float64 0.5145 0.8575 -0.3264 ... 0.02396 -1.225
#     TSU       (Date_UTC, vals) float64 0.7446 0.6675 -0.3343 ... -0.01711 -1.449
#     TUC       (Date_UTC, vals) float64 -0.307 -0.9517 0.4427 ... -0.03699 0.3674
#     TWN       (Date_UTC, vals) float64 -0.3478 -0.9376 -0.3144 ... nan nan nan
#     UMQ       (Date_UTC, vals) float64 0.03114 -0.9995 ... -0.001211 0.7152
#     UPN       (Date_UTC, vals) float64 0.1703 -0.9854 ... 0.0005554 0.7265
#     UPS       (Date_UTC, vals) float64 0.9927 0.1205 0.626 ... -0.005628 0.5475
#     VAL       (Date_UTC, vals) float64 -0.9805 0.1968 ... 0.0009971 0.4405
#     VIC       (Date_UTC, vals) float64 0.7883 -0.6154 0.5981 ... -0.05156 0.6396
#     VIZ       (Date_UTC, vals) float64 -0.7333 0.6799 0.8224 ... nan nan nan
#     VSS       (Date_UTC, vals) float64 0.9839 -0.1787 -0.1912 ... nan nan nan
#     WNG       (Date_UTC, vals) float64 0.7446 0.6675 0.5588 ... -0.002978 0.4718
#     YAP       (Date_UTC, vals) float64 0.3754 -0.9269 0.01911 ... nan nan nan
#     YKC       (Date_UTC, vals) float64 0.5875 -0.8092 0.7726 ... -0.0202 0.8196
#     YOR       (Date_UTC, vals) float64 0.2955 0.9553 0.5687 ... -0.1306 0.4664
#     ZYK       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     ATU       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     FYU       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     MCR       (Date_UTC, vals) float64 nan nan nan nan ... -0.9309 0.01646 0.687
#     PGC       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     FIT       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     PBK       (Date_UTC, vals) float64 nan nan nan ... -0.8025 -0.002095 0.7265
#     QSB       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     DSO       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     AQU       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     CDC       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     ARC       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     DRW       (Date_UTC, vals) float64 nan nan nan nan ... 2.021 -0.158 -1.551
#     LMM       (Date_UTC, vals) float64 nan nan nan ... -0.3195 -0.002095 -1.455
#     DNB       (Date_UTC, vals) float64 nan nan nan ... -1.111 0.0005554 0.656
#     IGC       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     ISK       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan
#     TAR       (Date_UTC, vals) float64 nan nan nan nan nan ... nan nan nan nan

# %%
def make_generator(mag_files, ss_file, stats_file, data_interval, prediction_interval):
    """My data generator feeding function
    
    Inputs:
        mag_files: list of magnetometer data file names
        ss_file: string file containing substorm data
        stats_file: string file containing mean and std
        data_interval: number of minutes for data interval
        prediction_interval: number of minutes for prediction interval
        
    Outputs:
        gen: the generator function
    
    What this needs to do:
        - load the i-th data file
        - strip away the unused variables
        - break the data into batches
            - time series for each station
            - sin(MLT), cos(MLT) and MLAT for each station
            - planet scale parameters
            - labels:
                - yes/no
                - time [0,1] for interval                           ------| for first substorm
                - location [sin(MLT), cos(MLT), MLAT in [-1,1]]     ------|
        - for the station time series':
            - remove stations with too many nans
            - outliers and remaining NaNs
            - remove mean, scale by STD
            - shuffle up stations? other augmentations?
        - yield (station x time x component), MLT, MLAT, planet params, targets
        - when current file is finished, load up next file
    """
    
    stats = np.load(stats_file)
    mean = stats['mean']
    std = stats['std']
    
    ss = pd.read_csv(ss_file)
    ss.index = pd.to_datetime(ss.Date_UTC)
    ss = ss.drop(columns=['Date_UTC'])
    
    data_dt = np.timedelta64(data_interval, 'm')
    predict_dt = np.timedelta64(prediction_interval, 'm')        
    
    def gen():
        
        for file in mag_files:
            print(file)
            
            dataset = xr.open_dataset(file).sel(dim_1=['MLT','MLAT','N','E','Z'])
            
            da = dataset.to_array().values
            sinmlt = np.sin(da[:,:,0])
            cosmlt = np.cos(da[:,:,0])
            mlat = da[:,:,1] / 90
            nez = (da[:,:,2:] - mean) / std

            data = np.concatenate((sinmlt[:,:,None], cosmlt[:,:,None], mlat[:,:,None], nez), axis=2)

            mag_data = xr.Dataset({st: (['Date_UTC', 'vals'], data[i]) for i,st in enumerate(dataset)},
                                  coords={'Date_UTC': dataset.Date_UTC, 'vals': ['SINMLT','COSMLT','MLAT','N','E','Z']})
            
            del dataset
            
            time_idx = mag_data.Date_UTC[0].values
            
            while True:
                
                if time_idx + data_dt > mag_data.Date_UTC[-1].values:
                    break
                
                # select time slice
                chunk = mag_data.sel(Date_UTC=slice(time_idx, time_idx + data_dt))     
                
                # skip if there is missing data
                if chunk.Date_UTC.shape[0] != data_interval + 1:
                    time_idx += data_dt
                    continue
                    
                # filter out stations with NaNs
                cond = np.isnan(chunk).any(dim=['Date_UTC', 'vals'])
                drop = [st for st in cond if cond[st]]
                chunk = chunk.drop(drop)
                
                # mag data
                mag_chunk = chunk.sel(vals=['N','E','Z']).to_array()
                
                # MLT / MLAT data
                mlat = chunk.sel(vals='MLAT').to_array()[:,0]
                sinmlt = chunk.sel(vals='SINMLT').to_array()[:,data_interval//2]
                cosmlt = chunk.sel(vals='COSMLT').to_array()[:,data_interval//2]
                st_loc = np.stack((sinmlt, cosmlt, mlat), axis=1)
                
                # planet scale parameters
                
                # increment time index
                time_idx += data_dt
                # create target
                target_chunk = ss[time_idx:time_idx+predict_dt]
                ss_occurred = len(target_chunk) > 0
                time = 0
                location = (0, 0, 0)
                if ss_occurred:
                    first = target_chunk.iloc[0]
                    time = (first.name - (time_idx)).total_seconds() / (200 * 60)
                    location = (np.sin(first['MLT'] * 2 * np.pi / 24), 
                                np.cos(first['MLT'] * 2 * np.pi / 24), 
                                first['MLAT']/90)
                    
                yield mag_chunk, st_loc, ss_occurred, time, location
                
            del mag_data
                
    return gen

# %%
mag_files = glob.glob("mag_data*.nc")
ss_file = ss_file = "substorms_2000_2018.csv"
stats_file = "statistics.npz"
data_interval = 120
prediction_interval = 250

gen = make_generator(mag_files, ss_file, stats_file, data_interval, prediction_interval)

dataset = tf.data.Dataset.from_generator(gen,
                                         output_types = (tf.float32, tf.float32, tf.bool, tf.float32, tf.float32),
                                         output_shapes = (tf.TensorShape([None, data_interval+1, 3]),
                                                          tf.TensorShape([None, 3]),
                                                          tf.TensorShape([]),
                                                          tf.TensorShape([]),
                                                          tf.TensorShape([3]))
                                        )

dataset = dataset.repeat()

iter = dataset.make_initializable_iterator()
el = iter.get_next()

import time
t = time.time()
EPOCHS = 10
with tf.Session() as sess:
    sess.run(iter.initializer)
    for i in range(EPOCHS):
        mag, st_loc, occ, ss_t, ss_loc = sess.run(el)

total_time = time.time() - t
print("Total Time: ", total_time)
print("Time per epoch: ", total_time/EPOCHS)
print(mag.shape)
# Out:
# mag_data_2000.nc
# Total Time:  11.662115573883057
# Time per epoch:  1.1662115573883056
# (165, 121, 3)
